# %% [markdown]
# # Cohen’s Kappa
#
# ### expert vs gpt-5

# %%
from sklearn.metrics import cohen_kappa_score

# expert and model labels
expert = ['yes','no','yes','no','yes','no','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','no','yes','yes','yes','no','yes','no','no','no','yes','yes','yes','yes','yes','no','yes','yes','no','no','no','no','no','yes','no','yes','yes','no','no','no','yes','no','no','yes','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes']
model  = ['yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','no','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','no','no','yes','no','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes']

kappa = cohen_kappa_score(expert, model)
print("Cohen's kappa:", round(kappa, 3))
# Out:
# Cohen's kappa: 0.424

# %% [markdown]
# ### expert vs gpt-4

# %%
from sklearn.metrics import cohen_kappa_score

# expert and model labels
expert = ['yes','no','yes','no','yes','no','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','no','yes','yes','yes','no','yes','no','no','no','yes','yes','yes','yes','yes','no','yes','yes','no','no','no','no','no','yes','no','yes','yes','no','no','no','yes','no','no','yes','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes']
model  = ['yes','yes','yes','no','yes','yes','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','no','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes']

kappa = cohen_kappa_score(expert, model)
print("Cohen's kappa:", round(kappa, 3))
# Out:
# Cohen's kappa: 0.38

# %% [markdown]
# ### non-expert vs gpt-5

# %%
from sklearn.metrics import cohen_kappa_score

# expert and model labels
expert = ['yes','yes','yes','yes','yes','no','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes','no','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','no','yes','yes','no','yes','no','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes']
model  = ['yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','no','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','no','no','yes','no','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes']

kappa = cohen_kappa_score(expert, model)
print("Cohen's kappa:", round(kappa, 3))
# Out:
# Cohen's kappa: 0.762

# %% [markdown]
# ### non-expert vs gpt-4

# %%
from sklearn.metrics import cohen_kappa_score

# expert and model labels
expert = ['yes','yes','yes','yes','yes','no','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes','no','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','no','yes','yes','no','yes','no','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes']
model  = ['yes','yes','yes','no','yes','yes','yes','no','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','no','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes']

kappa = cohen_kappa_score(expert, model)
print("Cohen's kappa:", round(kappa, 3))
# Out:
# Cohen's kappa: 0.691

# %% [markdown]
# # Fleiss’ Kappa

# %%
from statsmodels.stats.inter_rater import fleiss_kappa
import numpy as np

# each row = one case (e.g., abstract)
# each column = number of raters who chose a given category
# example: 3 raters, 2 categories ("yes", "no")
ratings = np.array([
[3, 0],
[2, 1],
[3, 0],
[2, 1],
[3, 0],
[1, 2],
[3, 0],
[0, 3],
[3, 0],
[3, 0],
[3, 0],
[3, 0],
[0, 3],
[3, 0],
[3, 0],
[3, 0],
[3, 0],
[2, 1],
[2, 1],
[3, 0],
[3, 0],
[3, 0],
[0, 3],
[3, 0],
[0, 3],
[2, 1],
[2, 1],
[3, 0],
[3, 0],
[3, 0],
[3, 0],
[3, 0],
[2, 1],
[3, 0],
[3, 0],
[2, 1],
[2, 1],
[2, 1],
[0, 3],
[1, 2],
[3, 0],
[0, 3],
[3, 0],
[3, 0],
[0, 3],
[2, 1],
[1, 2],
[3, 0],
[2, 1],
[2, 1],
[3, 0],
[3, 0],
[0, 3],
[3, 0],
[3, 0],
[3, 0],
[3, 0],
[2, 1],
[3, 0],
[3, 0],
[3, 0],
[3, 0],
])

fleiss = fleiss_kappa(ratings)
print("Fleiss' Kappa:", round(fleiss, 3))
# Out:
# Fleiss' Kappa: 0.494
